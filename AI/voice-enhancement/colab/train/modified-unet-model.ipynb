# %%
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
import tensorflow as tf

print(tf.__version__)

# Nested block (skip connections with multiple convolutions)
def conv_block(x, filters, kernel_size=3, padding='same', activation='leaky_relu', kernel_initializer='he_normal'):
    conv = Conv2D(filters, kernel_size, padding=padding, kernel_initializer=kernel_initializer)(x)
    if activation == 'leaky_relu':
        conv = LeakyReLU()(conv)
    else:
        conv = Activation(activation)(conv)
    conv = Conv2D(filters, kernel_size, padding=padding, kernel_initializer=kernel_initializer)(conv)
    if activation == 'leaky_relu':
        conv = LeakyReLU()(conv)
    else:
        conv = Activation(activation)(conv)
    return conv

# UNet++ network
def unet_modify(pretrained_weights=None, input_size=(128, 128, 1)):
    size_filter_in = 16
    kernel_init = 'he_normal'
    activation_layer = None  # For convolution blocks
    
    inputs = Input(input_size)
    
    # Encoder path
    conv1_0 = conv_block(inputs, size_filter_in)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1_0)
    
    conv2_0 = conv_block(pool1, size_filter_in * 2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2_0)
    
    conv3_0 = conv_block(pool2, size_filter_in * 4)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3_0)
    
    conv4_0 = conv_block(pool3, size_filter_in * 8)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4_0)
    
    conv5_0 = conv_block(pool4, size_filter_in * 16)
    
    # Decoder path (with nested connections)
    conv4_1 = concatenate([conv4_0, UpSampling2D(size=(2, 2))(conv5_0)], axis=-1)
    conv4_1 = conv_block(conv4_1, size_filter_in * 8)
    
    conv3_2 = concatenate([conv3_0, UpSampling2D(size=(2, 2))(conv4_1)], axis=-1)
    conv3_2 = conv_block(conv3_2, size_filter_in * 4)
    
    conv2_3 = concatenate([conv2_0, UpSampling2D(size=(2, 2))(conv3_2)], axis=-1)
    conv2_3 = conv_block(conv2_3, size_filter_in * 2)
    
    conv1_4 = concatenate([conv1_0, UpSampling2D(size=(2, 2))(conv2_3)], axis=-1)
    conv1_4 = conv_block(conv1_4, size_filter_in)
    
    # Final convolutional layer
    conv_final = Conv2D(1, (1, 1), activation='tanh')(conv1_4)
    
    model = Model(inputs, conv_final)
    
    model.compile(optimizer='adam', loss=tf.keras.losses.Huber(), metrics=['mae'])
    
    if pretrained_weights:
        model.load_weights(pretrained_weights)
    
    return model

# %%
root_path = '/kaggle/input/voice-enhancement'

# %%
import numpy as np

X_in = np.load(root_path + '/spectrogram/noisy_voice_amp_db.npy')
X_ou = np.load(root_path + '/spectrogram/voice_amp_db.npy')

n_samples = int(X_in.shape[0] * 0.5)

X_in = X_in[n_samples:]
X_ou = X_ou[n_samples:]

X_ou = X_in - X_ou

# %%
#to scale between -1 and 1
X_in = (X_in + 46)/50
X_ou = (X_ou -6 )/82

print(X_in.shape)
#Check new distribution
# print(stats.describe(X_in.reshape(-1,1)))
# print(stats.describe(X_ou.reshape(-1,1)))
# Out:
# (20000, 128, 128)

# %%
noise_std = 0.05  
noise = np.random.normal(0, noise_std, X_in.shape)
X_in = X_in + noise
X_ou= X_ou + noise

# %%
print(X_in.shape)
# Out:
# (20000, 128, 128)

# %%
print(X_in.shape,X_ou.shape)
# Out:
# (20000, 128, 128) (20000, 128, 128)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler

#Reshape for training
X_in = X_in[:,:,:]
X_in = X_in.reshape(X_in.shape[0],X_in.shape[1],X_in.shape[2],1)
X_ou = X_ou[:,:,:]
X_ou = X_ou.reshape(X_ou.shape[0],X_ou.shape[1],X_ou.shape[2],1)

X_train, X_test, y_train, y_test = train_test_split(X_in, X_ou, test_size=0.2, random_state=42)

#If training from pre-trained weights
generator_nn = unet_modify(input_size=(128, 128, 1))  
#generator_nn=unet_modify(pretrained_weights = '/kaggle/working/model-037-0.007457.keras')

#If training from scratch
#generator_nn=unet()
#Save best models to disk
checkpoint = ModelCheckpoint('/kaggle/working/model-{epoch:03d}-{val_loss:06f}.keras', 
                             verbose=1, monitor='val_loss', save_best_only=True, mode='auto')
generator_nn.summary()
#Training



history = generator_nn.fit(X_train, y_train, epochs=100, batch_size=80, shuffle=True, callbacks=[checkpoint], verbose=1, validation_data=(X_test, y_test))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 126 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      2,320 │ leaky_re_lu[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 64, 64,    │          0 │ conv2d_2[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │      9,248 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ leaky_re_lu_3[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │     36,928 │ leaky_re_lu_4[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ leaky_re_lu_5[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 16, 16,    │          0 │ conv2d_6[0][0]    │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    147,584 │ leaky_re_lu_6[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │          0 │ leaky_re_lu_7[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 8, 8, 256) │          0 │ conv2d_8[0][0]    │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ leaky_re_lu_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 8, 8, 256) │          0 │ conv2d_9[0][0]    │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ leaky_re_lu_9[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ leaky_re_lu_7[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ leaky_re_lu_7[0]… │
# │ (Concatenate)       │ 384)              │            │ up_sampling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 64, 64,    │          0 │ leaky_re_lu_5[0]… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ leaky_re_lu_5[0]… │
# │ (Concatenate)       │ 192)              │            │ up_sampling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 128, 128,  │          0 │ leaky_re_lu_3[0]… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ leaky_re_lu_3[0]… │
# │ (Concatenate)       │ 96)               │            │ up_sampling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 16, 16,    │          0 │ conv2d_10[0][0]   │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ leaky_re_lu_1[0]… │
# │ (Concatenate)       │ 48)               │            │ up_sampling2d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 64,    │     27,680 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 32, 32,    │          0 │ conv2d_12[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │    147,584 │ leaky_re_lu_10[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │      6,928 │ concatenate_6[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 64, 64,    │          0 │ conv2d_16[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │     36,928 │ leaky_re_lu_12[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 16, 16,    │          0 │ conv2d_11[0][0]   │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_22      │ (None, 128, 128,  │          0 │ conv2d_22[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 64, 64,    │      9,248 │ leaky_re_lu_16[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 32, 32,    │          0 │ conv2d_13[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 32, 32,    │          0 │ leaky_re_lu_11[0… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │      2,320 │ leaky_re_lu_22[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 64, 64,    │          0 │ conv2d_17[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 64, 64,    │          0 │ leaky_re_lu_13[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ leaky_re_lu_5[0]… │
# │ (Concatenate)       │ 256)              │            │ leaky_re_lu_13[0… │
# │                     │                   │            │ up_sampling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_23      │ (None, 128, 128,  │          0 │ conv2d_23[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 128, 128,  │          0 │ leaky_re_lu_17[0… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 64, 64,    │          0 │ leaky_re_lu_3[0]… │
# │ (Concatenate)       │ 128)              │            │ leaky_re_lu_17[0… │
# │                     │                   │            │ up_sampling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │    147,520 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ leaky_re_lu_1[0]… │
# │ (Concatenate)       │ 64)               │            │ leaky_re_lu_23[0… │
# │                     │                   │            │ up_sampling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 64, 64,    │     36,896 │ concatenate_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 32, 32,    │          0 │ conv2d_14[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 128, 128,  │      9,232 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_18      │ (None, 64, 64,    │          0 │ conv2d_18[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │     36,928 │ leaky_re_lu_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_24      │ (None, 128, 128,  │          0 │ conv2d_24[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 64, 64,    │      9,248 │ leaky_re_lu_18[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 32, 32,    │          0 │ conv2d_15[0][0]   │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 128, 128,  │      2,320 │ leaky_re_lu_24[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_19      │ (None, 64, 64,    │          0 │ conv2d_19[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 64, 64,    │          0 │ leaky_re_lu_15[0… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_25      │ (None, 128, 128,  │          0 │ conv2d_25[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 128, 128,  │          0 │ leaky_re_lu_19[0… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ leaky_re_lu_3[0]… │
# │ (Concatenate)       │ 160)              │            │ leaky_re_lu_17[0… │
# │                     │                   │            │ leaky_re_lu_19[0… │
# │                     │                   │            │ up_sampling2d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 128, 128,  │          0 │ leaky_re_lu_1[0]… │
# │ (Concatenate)       │ 80)               │            │ leaky_re_lu_23[0… │
# │                     │                   │            │ leaky_re_lu_25[0… │
# │                     │                   │            │ up_sampling2d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 64,    │     46,112 │ concatenate_5[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │     11,536 │ concatenate_8[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_20      │ (None, 64, 64,    │          0 │ conv2d_20[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_26      │ (None, 128, 128,  │          0 │ conv2d_26[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64,    │      9,248 │ leaky_re_lu_20[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 128, 128,  │      2,320 │ leaky_re_lu_26[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_21      │ (None, 64, 64,    │          0 │ conv2d_21[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_27      │ (None, 128, 128,  │          0 │ conv2d_27[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 128, 128,  │          0 │ leaky_re_lu_21[0… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 128, 128,  │          0 │ leaky_re_lu_1[0]… │
# │ (Concatenate)       │ 96)               │            │ leaky_re_lu_23[0… │
# │                     │                   │            │ leaky_re_lu_25[0… │
# │                     │                   │            │ leaky_re_lu_27[0… │
# │                     │                   │            │ up_sampling2d_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 128, 128,  │     13,840 │ concatenate_9[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_28      │ (None, 128, 128,  │          0 │ conv2d_28[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 128, 128,  │      2,320 │ leaky_re_lu_28[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_29      │ (None, 128, 128,  │          0 │ conv2d_29[0][0]   │
# │ (LeakyReLU)         │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │         17 │ leaky_re_lu_29[0… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,289,857 (8.74 MB)
#  Trainable params: 2,289,857 (8.74 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730537201.725736     126 service.cc:145] XLA service 0x78df1c0ac9a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730537201.726408     126 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1730537230.109052     126 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0073 - mae: 0.0873
# Epoch 1: val_loss improved from inf to 0.00714, saving model to /kaggle/working/model-001-0.007145.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 227ms/step - loss: 0.0073 - mae: 0.0873 - val_loss: 0.0071 - val_mae: 0.0854
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0069 - mae: 0.0853
# Epoch 2: val_loss did not improve from 0.00714
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0069 - mae: 0.0853 - val_loss: 0.0072 - val_mae: 0.0864
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0067 - mae: 0.0842
# Epoch 3: val_loss improved from 0.00714 to 0.00693, saving model to /kaggle/working/model-003-0.006927.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 212ms/step - loss: 0.0067 - mae: 0.0842 - val_loss: 0.0069 - val_mae: 0.0860
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0066 - mae: 0.0838
# Epoch 4: val_loss improved from 0.00693 to 0.00689, saving model to /kaggle/working/model-004-0.006889.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 212ms/step - loss: 0.0066 - mae: 0.0838 - val_loss: 0.0069 - val_mae: 0.0848
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0065 - mae: 0.0828
# Epoch 5: val_loss did not improve from 0.00689
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0065 - mae: 0.0828 - val_loss: 0.0069 - val_mae: 0.0844
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0063 - mae: 0.0819
# Epoch 6: val_loss did not improve from 0.00689
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0063 - mae: 0.0819 - val_loss: 0.0069 - val_mae: 0.0851
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0062 - mae: 0.0808
# Epoch 7: val_loss did not improve from 0.00689
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0062 - mae: 0.0808 - val_loss: 0.0069 - val_mae: 0.0844
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0060 - mae: 0.0800
# Epoch 8: val_loss improved from 0.00689 to 0.00689, saving model to /kaggle/working/model-008-0.006889.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 212ms/step - loss: 0.0060 - mae: 0.0801 - val_loss: 0.0069 - val_mae: 0.0839
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0060 - mae: 0.0797
# Epoch 9: val_loss did not improve from 0.00689
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0060 - mae: 0.0797 - val_loss: 0.0070 - val_mae: 0.0845
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0058 - mae: 0.0788
# Epoch 10: val_loss improved from 0.00689 to 0.00685, saving model to /kaggle/working/model-010-0.006855.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 212ms/step - loss: 0.0058 - mae: 0.0788 - val_loss: 0.0069 - val_mae: 0.0839
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0058 - mae: 0.0784
# Epoch 11: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0058 - mae: 0.0784 - val_loss: 0.0070 - val_mae: 0.0841
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0056 - mae: 0.0774
# Epoch 12: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0056 - mae: 0.0774 - val_loss: 0.0070 - val_mae: 0.0840
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0056 - mae: 0.0770
# Epoch 13: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0056 - mae: 0.0770 - val_loss: 0.0070 - val_mae: 0.0856
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0053 - mae: 0.0754
# Epoch 14: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0053 - mae: 0.0754 - val_loss: 0.0069 - val_mae: 0.0839
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0052 - mae: 0.0749
# Epoch 15: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0052 - mae: 0.0749 - val_loss: 0.0072 - val_mae: 0.0843
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0052 - mae: 0.0749
# Epoch 16: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0052 - mae: 0.0749 - val_loss: 0.0070 - val_mae: 0.0836
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0051 - mae: 0.0739
# Epoch 17: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0051 - mae: 0.0739 - val_loss: 0.0071 - val_mae: 0.0853
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0049 - mae: 0.0728
# Epoch 18: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0049 - mae: 0.0728 - val_loss: 0.0069 - val_mae: 0.0837
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0049 - mae: 0.0726
# Epoch 19: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0049 - mae: 0.0726 - val_loss: 0.0070 - val_mae: 0.0838
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0048 - mae: 0.0716
# Epoch 20: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0048 - mae: 0.0716 - val_loss: 0.0071 - val_mae: 0.0846
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0047 - mae: 0.0711
# Epoch 21: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0047 - mae: 0.0711 - val_loss: 0.0070 - val_mae: 0.0836
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0047 - mae: 0.0707
# Epoch 22: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0047 - mae: 0.0707 - val_loss: 0.0071 - val_mae: 0.0841
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0046 - mae: 0.0698
# Epoch 23: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0046 - mae: 0.0698 - val_loss: 0.0071 - val_mae: 0.0847
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0045 - mae: 0.0693
# Epoch 24: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0045 - mae: 0.0693 - val_loss: 0.0071 - val_mae: 0.0837
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0044 - mae: 0.0687
# Epoch 25: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - loss: 0.0044 - mae: 0.0687 - val_loss: 0.0071 - val_mae: 0.0833
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0044 - mae: 0.0684
# Epoch 26: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0044 - mae: 0.0684 - val_loss: 0.0070 - val_mae: 0.0832
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0043 - mae: 0.0680
# Epoch 27: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0043 - mae: 0.0680 - val_loss: 0.0071 - val_mae: 0.0843
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0043 - mae: 0.0678
# Epoch 28: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0043 - mae: 0.0678 - val_loss: 0.0072 - val_mae: 0.0838
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0042 - mae: 0.0670
# Epoch 29: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0042 - mae: 0.0670 - val_loss: 0.0072 - val_mae: 0.0841
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0042 - mae: 0.0666
# Epoch 30: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0042 - mae: 0.0666 - val_loss: 0.0071 - val_mae: 0.0840
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0041 - mae: 0.0664
# Epoch 31: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0041 - mae: 0.0664 - val_loss: 0.0072 - val_mae: 0.0838
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0040 - mae: 0.0657
# Epoch 32: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0040 - mae: 0.0657 - val_loss: 0.0071 - val_mae: 0.0834
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0040 - mae: 0.0652
# Epoch 33: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0040 - mae: 0.0652 - val_loss: 0.0072 - val_mae: 0.0836
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0040 - mae: 0.0651
# Epoch 34: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - loss: 0.0040 - mae: 0.0652 - val_loss: 0.0072 - val_mae: 0.0839
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0040 - mae: 0.0651
# Epoch 35: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0040 - mae: 0.0651 - val_loss: 0.0072 - val_mae: 0.0847
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0039 - mae: 0.0647
# Epoch 36: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0039 - mae: 0.0647 - val_loss: 0.0073 - val_mae: 0.0839
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0038 - mae: 0.0641
# Epoch 37: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0038 - mae: 0.0641 - val_loss: 0.0072 - val_mae: 0.0843
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0038 - mae: 0.0639
# Epoch 38: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0038 - mae: 0.0639 - val_loss: 0.0073 - val_mae: 0.0844
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0038 - mae: 0.0636
# Epoch 39: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0038 - mae: 0.0636 - val_loss: 0.0072 - val_mae: 0.0838
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0038 - mae: 0.0635
# Epoch 40: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0038 - mae: 0.0635 - val_loss: 0.0073 - val_mae: 0.0845
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0037 - mae: 0.0630
# Epoch 41: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0037 - mae: 0.0630 - val_loss: 0.0073 - val_mae: 0.0839
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0037 - mae: 0.0628
# Epoch 42: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0037 - mae: 0.0628 - val_loss: 0.0073 - val_mae: 0.0837
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0037 - mae: 0.0625
# Epoch 43: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0037 - mae: 0.0625 - val_loss: 0.0072 - val_mae: 0.0841
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0036 - mae: 0.0623
# Epoch 44: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0036 - mae: 0.0623 - val_loss: 0.0072 - val_mae: 0.0839
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0036 - mae: 0.0620
# Epoch 45: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 222ms/step - loss: 0.0036 - mae: 0.0620 - val_loss: 0.0074 - val_mae: 0.0849
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0036 - mae: 0.0619
# Epoch 46: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0036 - mae: 0.0619 - val_loss: 0.0073 - val_mae: 0.0841
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0035 - mae: 0.0615
# Epoch 47: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0035 - mae: 0.0615 - val_loss: 0.0072 - val_mae: 0.0840
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0035 - mae: 0.0612
# Epoch 48: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0035 - mae: 0.0612 - val_loss: 0.0073 - val_mae: 0.0841
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0035 - mae: 0.0613
# Epoch 49: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0035 - mae: 0.0613 - val_loss: 0.0075 - val_mae: 0.0851
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0035 - mae: 0.0615
# Epoch 50: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0035 - mae: 0.0615 - val_loss: 0.0073 - val_mae: 0.0839
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0035 - mae: 0.0608
# Epoch 51: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0035 - mae: 0.0608 - val_loss: 0.0073 - val_mae: 0.0842
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0034 - mae: 0.0602
# Epoch 52: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0034 - mae: 0.0602 - val_loss: 0.0073 - val_mae: 0.0839
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0034 - mae: 0.0602
# Epoch 53: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0034 - mae: 0.0602 - val_loss: 0.0073 - val_mae: 0.0839
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0034 - mae: 0.0602
# Epoch 54: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0034 - mae: 0.0602 - val_loss: 0.0072 - val_mae: 0.0832
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0034 - mae: 0.0601
# Epoch 55: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0034 - mae: 0.0601 - val_loss: 0.0074 - val_mae: 0.0842
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0034 - mae: 0.0600
# Epoch 56: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0034 - mae: 0.0600 - val_loss: 0.0073 - val_mae: 0.0839
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0033 - mae: 0.0594
# Epoch 57: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0033 - mae: 0.0594 - val_loss: 0.0073 - val_mae: 0.0840
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0033 - mae: 0.0592
# Epoch 58: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0033 - mae: 0.0592 - val_loss: 0.0074 - val_mae: 0.0842
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0033 - mae: 0.0592
# Epoch 59: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0033 - mae: 0.0592 - val_loss: 0.0074 - val_mae: 0.0843
# Epoch 60/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0033 - mae: 0.0592
# Epoch 60: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0033 - mae: 0.0592 - val_loss: 0.0074 - val_mae: 0.0845
# Epoch 61/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0032 - mae: 0.0585
# Epoch 61: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0032 - mae: 0.0585 - val_loss: 0.0075 - val_mae: 0.0844
# Epoch 62/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0033 - mae: 0.0590
# Epoch 62: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0033 - mae: 0.0590 - val_loss: 0.0074 - val_mae: 0.0846
# Epoch 63/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0032 - mae: 0.0588
# Epoch 63: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0032 - mae: 0.0588 - val_loss: 0.0073 - val_mae: 0.0840
# Epoch 64/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0032 - mae: 0.0584
# Epoch 64: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0032 - mae: 0.0584 - val_loss: 0.0073 - val_mae: 0.0837
# Epoch 65/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0032 - mae: 0.0583
# Epoch 65: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0032 - mae: 0.0583 - val_loss: 0.0073 - val_mae: 0.0838
# Epoch 66/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0032 - mae: 0.0587
# Epoch 66: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0032 - mae: 0.0586 - val_loss: 0.0074 - val_mae: 0.0845
# Epoch 67/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0032 - mae: 0.0582
# Epoch 67: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - loss: 0.0032 - mae: 0.0582 - val_loss: 0.0073 - val_mae: 0.0838
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0032 - mae: 0.0582
# Epoch 68: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0032 - mae: 0.0582 - val_loss: 0.0073 - val_mae: 0.0843
# Epoch 69/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0031 - mae: 0.0578
# Epoch 69: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0031 - mae: 0.0578 - val_loss: 0.0074 - val_mae: 0.0836
# Epoch 70/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0031 - mae: 0.0579
# Epoch 70: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0031 - mae: 0.0579 - val_loss: 0.0074 - val_mae: 0.0837
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0031 - mae: 0.0575
# Epoch 71: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0031 - mae: 0.0575 - val_loss: 0.0075 - val_mae: 0.0853
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0031 - mae: 0.0575
# Epoch 72: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0031 - mae: 0.0575 - val_loss: 0.0075 - val_mae: 0.0845
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0031 - mae: 0.0571
# Epoch 73: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - loss: 0.0031 - mae: 0.0571 - val_loss: 0.0075 - val_mae: 0.0845
# Epoch 74/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0571
# Epoch 74: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0571 - val_loss: 0.0075 - val_mae: 0.0843
# Epoch 75/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0569
# Epoch 75: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0569 - val_loss: 0.0074 - val_mae: 0.0838
# Epoch 76/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0570
# Epoch 76: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0569 - val_loss: 0.0074 - val_mae: 0.0845
# Epoch 77/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0568
# Epoch 77: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0568 - val_loss: 0.0075 - val_mae: 0.0842
# Epoch 78/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0568
# Epoch 78: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0568 - val_loss: 0.0075 - val_mae: 0.0844
# Epoch 79/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0566
# Epoch 79: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0566 - val_loss: 0.0075 - val_mae: 0.0839
# Epoch 80/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0566
# Epoch 80: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0566 - val_loss: 0.0075 - val_mae: 0.0847
# Epoch 81/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0565
# Epoch 81: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0565 - val_loss: 0.0075 - val_mae: 0.0844
# Epoch 82/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0565
# Epoch 82: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0565 - val_loss: 0.0075 - val_mae: 0.0844
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0562
# Epoch 83: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0562 - val_loss: 0.0075 - val_mae: 0.0850
# Epoch 84/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0030 - mae: 0.0563
# Epoch 84: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0030 - mae: 0.0563 - val_loss: 0.0075 - val_mae: 0.0843
# Epoch 85/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0029 - mae: 0.0560
# Epoch 85: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0029 - mae: 0.0560 - val_loss: 0.0075 - val_mae: 0.0841
# Epoch 86/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0029 - mae: 0.0556
# Epoch 86: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0029 - mae: 0.0556 - val_loss: 0.0075 - val_mae: 0.0842
# Epoch 87/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0029 - mae: 0.0557
# Epoch 87: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0029 - mae: 0.0557 - val_loss: 0.0076 - val_mae: 0.0848
# Epoch 88/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0029 - mae: 0.0560
# Epoch 88: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0029 - mae: 0.0560 - val_loss: 0.0076 - val_mae: 0.0846
# Epoch 89/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0029 - mae: 0.0558
# Epoch 89: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0029 - mae: 0.0558 - val_loss: 0.0075 - val_mae: 0.0844
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0028 - mae: 0.0551
# Epoch 90: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0551 - val_loss: 0.0076 - val_mae: 0.0849
# Epoch 91/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0028 - mae: 0.0551
# Epoch 91: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0551 - val_loss: 0.0075 - val_mae: 0.0842
# Epoch 92/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0029 - mae: 0.0552
# Epoch 92: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0029 - mae: 0.0552 - val_loss: 0.0076 - val_mae: 0.0848
# Epoch 93/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0028 - mae: 0.0550
# Epoch 93: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0550 - val_loss: 0.0075 - val_mae: 0.0846
# Epoch 94/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0028 - mae: 0.0551
# Epoch 94: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0551 - val_loss: 0.0075 - val_mae: 0.0842
# Epoch 95/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0028 - mae: 0.0552
# Epoch 95: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0552 - val_loss: 0.0076 - val_mae: 0.0844
# Epoch 96/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0028 - mae: 0.0550
# Epoch 96: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0550 - val_loss: 0.0076 - val_mae: 0.0848
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0028 - mae: 0.0546
# Epoch 97: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0546 - val_loss: 0.0075 - val_mae: 0.0840
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0028 - mae: 0.0549
# Epoch 98: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0549 - val_loss: 0.0077 - val_mae: 0.0845
# Epoch 99/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0029 - mae: 0.0552
# Epoch 99: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0029 - mae: 0.0552 - val_loss: 0.0076 - val_mae: 0.0849
# Epoch 100/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0028 - mae: 0.0543
# Epoch 100: val_loss did not improve from 0.00685
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - loss: 0.0028 - mae: 0.0543 - val_loss: 0.0075 - val_mae: 0.0844

# %%
#Plot training and validation loss
from matplotlib import pyplot as plt
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.yscale('log')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#Predict and QC the output
X_pred_test = generator_nn.predict(X_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
id = 350
plt.imshow(X_test[id,:,:,0])

# %%
plt.imshow(y_test[id,:,:,0])

# %%
plt.imshow(X_pred_test[id,:,:,0])

# %%
generator_nn.save("/kaggle/working/unetplusplus-100%-data.keras")
